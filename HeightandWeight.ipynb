# %%
from pandas import Series, DataFrame
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import matplotlib


#read csv file
path="C:\\Users\\liste\\Downloads\\athlete_events.csv"
rf = pd.read_csv(path)

# %%
df_people = rf.groupby('Team')['Name'].count()
df_new = df_people.sort_values(ascending=[False])
df_new.head(10)
df_new.head(10).plot.pie(title='percentage of top 10 countries with people involved',shadow =True)

# %%
df_new.head(10)
# Out:
# Team
# United States    17847
# France           11988
# Great Britain    11404
# Italy            10260
# Germany           9326
# Canada            9279
# Japan             8289
# Sweden            8052
# Australia         7513
# Hungary           6547
# Name: Name, dtype: int64

# %%
df_medal = rf.groupby('Team')['Medal'].count()
df_numberMedal = df_medal.sort_values(ascending=[False])
df_numberMedal.head(10)
# Out:
# Team
# United States    5219
# Soviet Union     2451
# Germany          1984
# Great Britain    1673
# France           1550
# Italy            1527
# Sweden           1434
# Australia        1306
# Canada           1243
# Hungary          1127
# Name: Medal, dtype: int64

# %%
df_numberMedal.head(10).plot.pie(title='percentage of top 10 countries with the most medals',shadow =True)

# %%
sex = [196594, 74522]
mf = ['Male', 'Female']
colors = ['y', 'g']
plt.pie(sex, labels=mf, colors=colors, startangle=90, autopct='%.1f%%')
plt.show()

# %%
df_numberofsex = df_sex.sort_values(by='F', ascending = [False])
df_numberofsex.head(10)
# Out:
# Sex                 F        M
# Team
# United States  5368.0  12479.0
# Canada         3473.0   5806.0
# Great Britain  3188.0   8216.0
# Germany        2911.0   6415.0
# France         2743.0   9245.0
# Japan          2727.0   5562.0
# Australia      2697.0   4816.0
# China          2673.0   2302.0
# Italy          2504.0   7756.0
# Russia         2122.0   2800.0

# %%
df_sex=rf.groupby(['Height', 'Sport'])['Height'].count().unstack()

df_numberofsex = df_sex.sort_values(by='Height',ascending = [True])

df_sex.fillna(0)
df_sex.iloc[:10,:30].plot(kind='bar', stacked=True, figsize = (13,11))

# %%
df_sex=rf.groupby(['Height', 'Sport'])['Height'].count().unstack()

df_numberofsex = df_sex.sort_values(by='Height',ascending = [True])
df_sex.fillna(0)
df_sex.iloc[-10:-1,-30:-1].plot(kind='bar', stacked=True, figsize = (13,11))

# %%
# Out:
# 214.0
# 25.0
# 70.70239290053351
