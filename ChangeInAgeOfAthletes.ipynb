# %%
import pandas as pd
# %matplotlib inline

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

df = pd.read_csv("athlete_events.csv")

# %%
plt.figure(figsize=(25, 15))
sns.boxplot('Year', 'Age', data=df)
plt.title('Change in age of athletes in box plot')
# Out:
# Text(0.5, 1.0, 'Change in age of athletes in box plot')
